# %%
from benchmarks import benchmark
from equivariant_polynomials.groups.so2 import SO2RepresentationTheory, hilbert_series_so2

theory = SO2RepresentationTheory()
result = benchmark(
    theory,
    hilbert_series_so2,
    (1, -1),
    (2, 1),
    0,
    4,
    invariant_irrep=0,
    random_seed=0,
)
assert result["algebra"]["matches_hilbert"]
result
